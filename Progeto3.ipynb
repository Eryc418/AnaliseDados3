# %% [markdown]
# <a href="https://colab.research.google.com/github/Eryc418/AnaliseDados3/blob/main/Progeto3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Nova seção

# %%
df = pd.read_csv('/content/sample_data/vgsales.csv')#Obs: Decidi mudar de tema, o dataframe escolhido para fazer as tarefas e 1 e 2 eram muito pobres de dados (Portanto, peguei um dataframe que contem dados de vendas de videogames)
#Fonte: https://www.kaggle.com/gregorut/videogamesales - Venda de Video Games

# %%
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %%
df.describe()
# Out:
#                Rank          Year  ...   Other_Sales  Global_Sales
# count  16598.000000  16327.000000  ...  16598.000000  16598.000000
# mean    8300.605254   2006.406443  ...      0.048063      0.537441
# std     4791.853933      5.828981  ...      0.188588      1.555028
# min        1.000000   1980.000000  ...      0.000000      0.010000
# 25%     4151.250000   2003.000000  ...      0.000000      0.060000
# 50%     8300.500000   2007.000000  ...      0.010000      0.170000
# 75%    12449.750000   2010.000000  ...      0.040000      0.470000
# max    16600.000000   2020.000000  ...     10.570000     82.740000
#
# [8 rows x 7 columns]

# %%
df[df['Genre'] == 'Sports']#Busca por jogos do Genero Sports
# Out:
#         Rank                           Name  ... Other_Sales  Global_Sales
# 0          1                     Wii Sports  ...        8.46         82.74
# 3          4              Wii Sports Resort  ...        2.96         33.00
# 13        14                        Wii Fit  ...        2.15         22.72
# 14        15                   Wii Fit Plus  ...        1.79         22.00
# 77        78                        FIFA 16  ...        1.26          8.49
# ...      ...                            ...  ...         ...           ...
# 16576  16579              Rugby Challenge 3  ...        0.00          0.01
# 16578  16581  Outdoors Unleashed: Africa 3D  ...        0.00          0.01
# 16579  16582              PGA European Tour  ...        0.00          0.01
# 16581  16584                      Fit & Fun  ...        0.00          0.01
# 16587  16590       Mezase!! Tsuri Master DS  ...        0.00          0.01
#
# [2346 rows x 11 columns]

# %%
df[df['Global_Sales'] >= 22.00][['Global_Sales','Name', 'Year', 'Platform']] # Busca por todos os jogos que tiveram venda global acima ou igual a 22.00
# Out:
#     Global_Sales                         Name    Year Platform
# 0          82.74                   Wii Sports  2006.0      Wii
# 1          40.24            Super Mario Bros.  1985.0      NES
# 2          35.82               Mario Kart Wii  2008.0      Wii
# 3          33.00            Wii Sports Resort  2009.0      Wii
# 4          31.37     Pokemon Red/Pokemon Blue  1996.0       GB
# 5          30.26                       Tetris  1989.0       GB
# 6          30.01        New Super Mario Bros.  2006.0       DS
# 7          29.02                     Wii Play  2006.0      Wii
# 8          28.62    New Super Mario Bros. Wii  2009.0      Wii
# 9          28.31                    Duck Hunt  1984.0      NES
# 10         24.76                   Nintendogs  2005.0       DS
# 11         23.42                Mario Kart DS  2005.0       DS
# 12         23.10  Pokemon Gold/Pokemon Silver  1999.0       GB
# 13         22.72                      Wii Fit  2007.0      Wii
# ...

# %%
dfMelhor = df[df['Global_Sales'] >= 22.00][['Global_Sales','Name', 'Year', 'Platform']] # Busca por todos os jogos que tiveram venda global acima ou igual a 22.00

# %%
df.isnull()#Verificando se existem valores nulos
# Out:
#         Rank   Name  Platform  ...  JP_Sales  Other_Sales  Global_Sales
# 0      False  False     False  ...     False        False         False
# 1      False  False     False  ...     False        False         False
# 2      False  False     False  ...     False        False         False
# 3      False  False     False  ...     False        False         False
# 4      False  False     False  ...     False        False         False
# ...      ...    ...       ...  ...       ...          ...           ...
# 16593  False  False     False  ...     False        False         False
# 16594  False  False     False  ...     False        False         False
# 16595  False  False     False  ...     False        False         False
# 16596  False  False     False  ...     False        False         False
# 16597  False  False     False  ...     False        False         False
#
# [16598 rows x 11 columns]

# %%
df[df['Global_Sales'] <= 0.01][['Global_Sales','Name', 'Year', 'Platform']] # Buscar por piores vendas de videogames
# Out:
#        Global_Sales  ... Platform
# 15980          0.01  ...       PC
# 15981          0.01  ...      PSV
# 15982          0.01  ...      3DS
# 15983          0.01  ...       DS
# 15984          0.01  ...       DS
# ...             ...  ...      ...
# 16593          0.01  ...      GBA
# 16594          0.01  ...       GC
# 16595          0.01  ...      PS2
# 16596          0.01  ...       DS
# 16597          0.01  ...      GBA
#
# [618 rows x 4 columns]

# %%
dfPior = df[df['Global_Sales'] <= 0.01][['Global_Sales','Name', 'Year', 'Platform']]

# %%
concatenacao = pd.concat([dfMelhor, dfPior]) #Concatenação de melhores vendas de videogames com piores vendas
print(concatenacao)
# Out:
#        Global_Sales  ... Platform
# 0             82.74  ...      Wii
# 1             40.24  ...      NES
# 2             35.82  ...      Wii
# 3             33.00  ...      Wii
# 4             31.37  ...       GB
# ...             ...  ...      ...
# 16593          0.01  ...      GBA
# 16594          0.01  ...       GC
# 16595          0.01  ...      PS2
# 16596          0.01  ...       DS
# 16597          0.01  ...      GBA
#
# [633 rows x 4 columns]

# %%
pd.concat([dfMelhor, dfPior], axis=1) # Ao concatena as colunas usando os indices em comum das linhas o dataframe retornou alguns valores nulos (Mescla)
# Out:
#        Global_Sales                      Name  ...    Year Platform
# 0             82.74                Wii Sports  ...     NaN      NaN
# 1             40.24         Super Mario Bros.  ...     NaN      NaN
# 2             35.82            Mario Kart Wii  ...     NaN      NaN
# 3             33.00         Wii Sports Resort  ...     NaN      NaN
# 4             31.37  Pokemon Red/Pokemon Blue  ...     NaN      NaN
# ...             ...                       ...  ...     ...      ...
# 16593           NaN                       NaN  ...  2002.0      GBA
# 16594           NaN                       NaN  ...  2003.0       GC
# 16595           NaN                       NaN  ...  2008.0      PS2
# 16596           NaN                       NaN  ...  2010.0       DS
# 16597           NaN                       NaN  ...  2003.0      GBA
#
# [633 rows x 8 columns]

# %%
dfNovo = dfMelhor.groupby('Platform')

# %%
dfNovo.mean()
# Out:
#           Global_Sales         Year
# Platform
# DS           26.063333  2005.333333
# GB           28.243333  1994.666667
# NES          34.275000  1984.500000
# Wii          36.274286  2007.714286

# %%
Agr = df.agg(['mean', 'count', 'min', 'max'])

# %%
Agr
# Out:
#                Rank                          Name  ...   Other_Sales  Global_Sales
# mean    8300.605254                           NaN  ...      0.048063      0.537441
# count  16598.000000                         16598  ...  16598.000000  16598.000000
# min        1.000000                   '98 Koshien  ...      0.000000      0.010000
# max    16600.000000  ¡Shin Chan Flipa en colores!  ...     10.570000     82.740000
#
# [4 rows x 11 columns]

# %%
dfMelhor.plot() #Grafico com melhores vendas de videogames

# %%
dfPior.plot() #Grafico com piores vendas de videogames

# %%
df.plot() # Grafico dataFrame com todas as vendas
